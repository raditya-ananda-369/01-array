# %% [markdown]
# <a href="https://colab.research.google.com/github/raditya-ananda-369/01-array/blob/main/Soal_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TUGAS - SISTEM PENGELOLAAN NILAI MAHASISWA
# Struktur Data: Array (List)

import matplotlib.pyplot as plt

# 1. INPUT 10 NILAI
nilai = []

print("=== Input 10 Nilai Mahasiswa ===")
for i in range(10):
    n = float(input(f"Masukkan nilai mahasiswa ke-{i+1}: "))
    nilai.append(n)

print("\nData nilai:", nilai)


# 2. NILAI TERTINGGI & TERENDAH
print("\n=== Nilai Tertinggi & Terendah ===")
print("Nilai tertinggi:", max(nilai))
print("Nilai terendah :", min(nilai))


# 3. RATA-RATA
print("\n=== Rata-rata Nilai ===")
print("Rata-rata:", sum(nilai) / len(nilai))


# 4. JUMLAH MAHASISWA LULUS (>= 60)
lulus = 0
tidak_lulus = 0

for n in nilai:
    if n >= 60:
        lulus += 1
    else:
        tidak_lulus += 1

print("\n=== Data Kelulusan ===")
print("Lulus      :", lulus, "mahasiswa")
print("Tidak lulus:", tidak_lulus, "mahasiswa")

print("\n")
# 5. GRAFIK NILAI TERTINGGI & TERENDAH
plt.bar(range(1, 11), nilai)
plt.title("Grafik Nilai Tertinggi dan Terendah")
plt.xlabel("Mahasiswa ke-")
plt.ylabel("Nilai")
plt.show()
print("\n")

# 6. GRAFIK DATA KELULUSAN
plt.bar(["Lulus", "Tidak Lulus"], [lulus, tidak_lulus])
plt.title("Grafik Data Kelulusan Mahasiswa")
plt.xlabel("Status")
plt.ylabel("Jumlah Mahasiswa")
plt.show()

# 7. ANALISIS KOMPLEKSITAS TIAP OPERASI
print("\n=== Analisis Kompleksitas ===")
print("1. Input 10 nilai   -> O(n) : loop sebanyak jumlah data")
print("2. Cari tertinggi   -> O(n) : cek semua elemen satu per satu")
print("3. Cari terendah    -> O(n) : cek semua elemen satu per satu")
print("4. Hitung rata-rata -> O(n) : jumlahkan semua elemen")
print("5. Hitung kelulusan -> O(n) : cek semua elemen satu per satu")
print("6. Grafik kelulusan -> O(1) : datanya selalu 2 (lulus & tidak lulus)")
# Out:
# === Input 10 Nilai Mahasiswa ===
# Masukkan nilai mahasiswa ke-1: 90
# Masukkan nilai mahasiswa ke-2: 55
# Masukkan nilai mahasiswa ke-3: 76
# Masukkan nilai mahasiswa ke-4: 60
# Masukkan nilai mahasiswa ke-5: 80
# Masukkan nilai mahasiswa ke-6: 85
# Masukkan nilai mahasiswa ke-7: 90
# Masukkan nilai mahasiswa ke-8: 45
# Masukkan nilai mahasiswa ke-9: 65
# Masukkan nilai mahasiswa ke-10: 70
#
# Data nilai: [90.0, 55.0, 76.0, 60.0, 80.0, 85.0, 90.0, 45.0, 65.0, 70.0]
#
# === Nilai Tertinggi & Terendah ===
# Nilai tertinggi: 90.0
# Nilai terendah : 45.0
#
# === Rata-rata Nilai ===
# Rata-rata: 71.6
#
# === Data Kelulusan ===
# Lulus      : 8 mahasiswa
# Tidak lulus: 2 mahasiswa
# === Analisis Kompleksitas ===
# 1. Input 10 nilai   -> O(n) : loop sebanyak jumlah data
# 2. Cari tertinggi   -> O(n) : cek semua elemen satu per satu
# 3. Cari terendah    -> O(n) : cek semua elemen satu per satu
# 4. Hitung rata-rata -> O(n) : jumlahkan semua elemen
# 5. Hitung kelulusan -> O(n) : cek semua elemen satu per satu
# 6. Grafik kelulusan -> O(1) : datanya selalu 2 (lulus & tidak lulus)
